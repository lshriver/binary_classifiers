# %%
import sys
sys.path.append('/workspaces/projLevitate/')
from colors import Bcolors as bc

# %%
from qiskit import transpile
from qiskit_aer import Aer, AerSimulator, AerJob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspaces/projLevitate/notebook/quantum_example.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell://codespaces%2Bbug-free-sniffle-4jwwjpgpvxx735j5g/workspaces/projLevitate/notebook/quantum_example.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from qiskit import transpile
# ----> <a href='vscode-notebook-cell://codespaces%2Bbug-free-sniffle-4jwwjpgpvxx735j5g/workspaces/projLevitate/notebook/quantum_example.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> from qiskit_aer import Aer, AerSimulator, AerJob
#
# ModuleNotFoundError: No module named 'qiskit_aer'

# %% [markdown]
# # 🪄 Custom function generated by Albus.
# Purpose: It is meant to mimic an original Qiskit execute function.
#
# Parameters:
# - `circuts`: a QuantumCircuit or a list of QuantumCircuits we want to run.
# - `backend`: a backend where we execute circuits on. Defaults to `AerSimulator`.
# - `shots`: number of 'shots' for the execution. Defaults to 1024.
# - `kwargs`: additional arguments to pass the `backend.run()` method on

# %%
def execute(circuits, backend=None, shots=1024, **kwargs):
    if backend is None:
        backend = AerSimulator()
        
    # Transpile the circuits for the backend
    transpiled_circuits = transpile(circuits, backend)
    
    # Run the circuits on the backend
    job = backend.run(transpiled_circuits, shots=shots, **kwargs)
    
    return job

# %%
from qiskit import QuantumCircuit

# Create a simple quantum circuit
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)
qc.measure_all()

# Execute the circuit using execute.py script
job = execute(qc)
result = job.result()

# Print the result
print()
